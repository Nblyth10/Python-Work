# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = list(range(0,10))

# %%
import numpy as np

# %%
x = np.arange(0,10,0.01)

# %%
plt.plot(x,x**2)
plt.plot(x,x**3)

y = np.arange(2,7)

plt.fill_between(y,y**2,y**3, color = 'grey')
